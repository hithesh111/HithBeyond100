# %% [markdown]
# <div dir="ltr" style="text-align: left;" trbidi="on">
# <h2 style="text-align: left;">
# 100 Days of ML Day 124</h2>
# <h2 class="title-and-badge style-scope ytd-video-renderer" style="text-align: left;">
# This AI Senses Humans Through Walls </h2>
# Watched a video 'This AI Senses Humans Through Walls ' by 2 Minute Papers on Youtube.<br />
# <br />
# Videos:<br />
# <div class="title-and-badge style-scope ytd-video-renderer">
# <a aria-label="This Neural Network Regenerates…Kind Of 🦎 by Two Minute Papers 2 weeks ago 4 minutes, 49 seconds 69,098 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="https://www.youtube.com/watch?v=kBFMsY5ZP0o" id="video-title" title="This Neural Network Regenerates…Kind Of 🦎">This AI Senses Humans Through Walls 👀</a></div>
# </div>
